# %%
# Import libraries
import pandas as pd
import numpy as np

import warnings 
warnings.filterwarnings('ignore')

# %%
# Assign spreadsheet filename to `file`
file = 'data_sarah.xls'

# Load spreadsheet
xl = pd.ExcelFile(file)

# There are 18 sheets in total
mysheets = xl.sheet_names

description = [] # for the description of each sheet
df_raw = [] # for the df's returned by parsing the excel sheet

# Read in all descriptions and sheets
for i, sheet in enumerate(mysheets):

    # The top left cell of each sheet contains a description that puts the 
    # data in the sheet into context
    description.append(xl.parse(sheet, header=None, nrows=1)[0][0])

    # The actual data table starts in row 3
    df_raw.append(xl.parse(sheet, header = 2))
    
# Print one as an example
df_raw[5]
# Out:
#                  Theme                                           Question  \
# 0               Access  If you ask to make an appointment with a docto...
# 1               Access                                                NaN
# 2            Referrals  Thinking about the last time your GP referred ...
# 3            Referrals                                                NaN
# 4   At your GP surgery     How clean is your GP surgery or health centre?
# 5   At your GP surgery                                                NaN
# 6               Doctor  I felt that the doctor had all the information...
# 7               Doctor                                                NaN
# 8               Doctor  I felt confident in the doctor's ability to tr...
# 9               Doctor                                                NaN
# 10               Nurse  I felt that the nurse had all the information ...
# 11               Nurse                                                NaN
# 12               Nurse        The nurse was considerate and understanding
# 13               Nurse                                                NaN
# 14               Nurse  The nurse talked in a way that helped me under...
# 15               Nurse                                                NaN
# 16               Nurse  I felt confident in the nurse's ability to tre...
# 17               Nurse                                                NaN
# 18  Care and treatment  Are you involved as much as you want to be in ...
# 19  Care and treatment                                                NaN
# 20           Medicines  I knew enough about possible side effects of m...
# 21           Medicines                                                NaN
# 22           Medicines  I would know what to do if I had any problems ...
# 23           Medicines                                                NaN
# 24        Overall care       I am treated with kindness and understanding
# 25        Overall care                                                NaN
# 26        Out of Hours                   The time I waited was reasonable
# 27        Out of Hours                                                NaN
# 28        Out of Hours  I felt that the person had all the information...
# 29        Out of Hours                                                NaN
#
#    most deprived 1      deprived-2      deprived-3      deprived-4 COL1 COL2  \
# 0            0.853           0.849           0.930           0.974    -    -
# 1   (0.800 ,0.909)  (0.799 ,0.902)  (0.875 ,0.988)  (0.917 ,1.033)    -    -
# 2            1.240           1.193           1.102           1.082    +    +
# 3   (1.151 ,1.335)  (1.113 ,1.279)  (1.030 ,1.179)  (1.012 ,1.156)    +    +
# 4            1.572           1.307           1.214           1.072    +    +
# 5   (1.487 ,1.661)  (1.242 ,1.375)  (1.155 ,1.275)  (1.022 ,1.123)    +    +
# 6            1.135           1.109           1.043           0.995    +    +
# 7   (1.049 ,1.229)  (1.029 ,1.195)  (0.972 ,1.120)  (0.929 ,1.067)    +    +
# 8            1.048           1.029           1.018           0.941    N    N
# 9   (0.968 ,1.134)  (0.955 ,1.108)  (0.948 ,1.093)  (0.878 ,1.008)    N    N
# 10           1.249           1.199           1.088           1.133    +    +
# 11  (1.115 ,1.398)  (1.078 ,1.333)  (0.984 ,1.203)  (1.025 ,1.252)    +    +
# 12           1.446           1.260           1.071           1.173    +    +
# 13  (1.258 ,1.663)  (1.111 ,1.429)  (0.951 ,1.207)  (1.041 ,1.323)    +    +
# 14           1.553           1.316           1.203           1.181    +    +
# 15  (1.391 ,1.733)  (1.195 ,1.449)  (1.098 ,1.317)  (1.081 ,1.291)    +    +
# 16           1.328           1.188           1.077           1.161    +    +
# 17  (1.176 ,1.500)  (1.062 ,1.330)  (0.969 ,1.198)  (1.044 ,1.291)    +    +
# 18           0.836           0.858           0.899           0.963    -    -
# 19  (0.771 ,0.906)  (0.796 ,0.924)  (0.837 ,0.967)  (0.895 ,1.036)    -    -
# 20           1.200           1.162           1.083           1.078    +    +
# 21  (1.123 ,1.282)  (1.095 ,1.233)  (1.024 ,1.146)  (1.020 ,1.140)    +    +
# 22           1.109           1.099           1.024           1.048    +    +
# 23  (1.025 ,1.199)  (1.020 ,1.184)  (0.953 ,1.102)  (0.975 ,1.127)    +    +
# 24           1.121           1.080           1.086           1.008    +    +
# 25  (1.042 ,1.208)  (1.009 ,1.156)  (1.016 ,1.161)  (0.945 ,1.075)    +    +
# 26           1.062           1.013           0.993           0.919    N    N
# 27  (0.964 ,1.170)  (0.925 ,1.111)  (0.910 ,1.084)  (0.843 ,1.002)    N    N
# 28           1.075           1.113           1.015           0.931    N    +
# 29  (0.975 ,1.185)  (1.014 ,1.222)  (0.930 ,1.109)  (0.853 ,1.016)    N    +
#
#    COL3 COL4
# 0     -    N
# 1     -    N
# 2     +    +
# 3     +    +
# 4     +    +
# 5     +    +
# 6     N    N
# 7     N    N
# 8     N    N
# 9     N    N
# 10    N    +
# 11    N    +
# 12    N    +
# 13    N    +
# 14    +    +
# 15    +    +
# 16    N    +
# 17    N    +
# 18    -    N
# 19    -    N
# 20    +    +
# 21    +    +
# 22    N    N
# 23    N    N
# 24    +    N
# 25    +    N
# 26    N    N
# 27    N    N
# 28    N    N
# 29    N    N

# %%
df = [] # clean dataframes will go in here later

# iterate through all parsed sheets and clean/reformat them
for dfr in df_raw:
    
    # Remove COLx (they only describe information that is already contained 
    # in the other columns)
    cols = dfr.columns
    pattern = r'^COL*'
    cols_to_keep = cols[~cols.str.match(pattern)]
    dfr = dfr[cols_to_keep]
    
    # Because of how the Excel sheet was formatted, we need to split out the
    # odd rows
    
    # Create index lists for odd and even rows
    even = np.array(range(0, len(dfr), 2))
    odd = np.array(range(1, len(dfr), 2))
    
    # Separate dataframes - we will add the odd rows back into the df with the
    # even rows later
    df_clean = dfr.iloc[even, :].reset_index(drop=True) # even rows
    df_odd = dfr.iloc[odd, 2:].reset_index(drop=True) # odd rows
    
    # Melt dataframe into long shape
    df_clean = df_clean.melt(id_vars=['Theme', 'Question'], 
                 var_name='group', 
                 value_name='odds_ratio')
    
    # Theme and question are mostly missing because of the merged cells in the
    # Excel sheet, but they are ordered correctly, so I can just replace those
    # columns with the ones from the dataframe with the even rows
    df_odd['Theme'] = df_clean['Theme']
    df_odd['Question'] = df_clean['Question']
    
    # Melt the dataframe with the odd rows as well
    df_odd = df_odd.melt(id_vars=['Theme', 'Question'], 
                 var_name='group', 
                 value_name='conf')
    
    # Split the column with the confidence interval into separate columns
    conf_split = df_odd['conf'].str.replace(r'\(|\)', '').str.split(',', expand=True)
    # Add into the clean dataframe
    df_clean['conf_lower'] = conf_split[0]
    df_clean['conf_upper'] = conf_split[1]
    
    # lowercase column names
    df_clean.columns = df_clean.columns.str.lower()
        
    # convert columns with numbers to numeric type
    for colname in df_clean.columns[3:]:
        df_clean[colname] = pd.to_numeric(df_clean[colname])

    # Append clean dataframe to list
    df.append(df_clean)

# %%
description
# Out:
# ['Odds ratios by gender with females as the base group',
#  'Odds ratios by age, interpreted as the odds for a patient one year older than the mean age (of surveyed patients) compared to a patient who has the mean age. Note: The effect may seem quite small, but it must be remembered that the difference is for a one year increase in age and the survey covered a large age range.',
#  'Odds ratios by ethnicity with those identifying as white as the base group',
#  'Odds ratios by religion with those identifying as belonging to Church of Scotland as the base group',
#  'Odds ratios by sexual orientation with those identifying as heterosexual / straight as the base group',
#  'Odds ratios by deprivation (based on SIMD) with those in the least deprived quintile (Quntile 5) as the base group',
#  "Odds ratios by urban-rural classification (based on SG's 6-fold UR Classification) with those living in large urban areas as the base group",
#  'Odds ratios by work status with those who are retired as the base group',
#  'Odds ratios by carer hours with those who did not identify as a carer as the base group',
#  'Odds ratios by health status with those who reported a "good" health status as the base group',
#  'Odds ratios by limitation of day-to-day activities with those who reported they had not health problem that limited their day-to-day activities as the base group',
#  'Odds ratios by interpretation, translation or other communication support needs with those who did not require this support as the base group',
#  'Odds ratios by long-term condition with those who did not have that particular condition as the base group',
#  'Odds ratios by GP Practice size with those registered to a practice with between 2,500 and 4,999 patients as the base group',
#  'Odds ratios by percentage of the GP Practice list in deprived areas, interpreted as a one percentage point increase in the mean percentage of the practice list from the 15% most deprived areas compared to the mean percentage',
#  'Odds ratios by frequency of contact with the GP Practice with those contacting their GP Practice between 2 and 4 times in the last year as the base group',
#  'Odds ratios by first OOH service contacted with those contacting NHS 24 as the base group',
#  'Odds ratios by first OOH service ended up being treated or advised by with those who received phone advice only as the base group']

# %%
# Add additional information from the descriptions, then merge

info = [["Gender", "Female"],
        ["Age", "Mean age"],
        ["Ethnicity", "White"],
        ["Religion",  "Church of Scotland"],
        ["Sexual orientation", "Heterosexual"],
        ["Deprivation (SIMD)", "Quintile 5"],
        ["Urban-Rural", "Large urban areas"],
        ["Work Status", "Retired"],
        ["Carers", "Not a carer"],
        ["Health status", "Good"],
        ["Limitation of day-to-day activities", "Not limited"],
        ["Interpretation, translation or other communication support needs", "No"],
        ["Long-term condition", "None"],
        ["GP Practice Size", "2500 - 4999"],
        ["Percentage of GP practice list in 15% of most deprived areas", "Mean"],
        ["Frequency of contact with GP Practice", "2-4 times"],
        ["First OOH service contacted", "NHS24"],
        ["First OOH service treated or advised by", "Phone advice only"]]

# Insert two additional columns for the additional information
for i in range(len(df)):
    df[i].insert(2, 'characteristic', info[i][0])
    df[i].insert(3, 'base_group', info[i][1])

# Concatenate all dataframes, yielding one big dataframe df which contains all our data
df = pd.concat(df)

# Reset index to number rows sequentially
df = df.reset_index(drop=True)

# %%
df
# Out:
#                    theme                                           question  \
# 0                 Access  Thinking of the last time you contacted this G...
# 1                 Access  The last time you needed to see or speak to a ...
# 2                 Access  If you ask to make an appointment with a docto...
# 3                 Access  When you arrange to see a doctor at your GP su...
# 4                 Access  Overall how would you rate the arrangements fo...
# 5                 Access  Overall how would you rate the arrangements fo...
# 6              Referrals  Thinking about the last time your GP referred ...
# 7     At your GP surgery  How helpful do you find the receptionists at y...
# 8     At your GP surgery  How do you feel about how long you usually hav...
# 9                 Doctor                          The doctor listened to me
# 10                Doctor  I felt that the doctor had all the information...
# 11                Doctor       The doctor was considerate and understanding
# 12                Doctor  The doctor talked in a way that helped me unde...
# 13                Doctor  I felt confident in the doctor's ability to tr...
# 14                Doctor                  I had enough time with the doctor
# 15                 Nurse                           The nurse listened to me
# 16                 Nurse  I felt that the nurse had all the information ...
# 17                 Nurse        The nurse was considerate and understanding
# 18                 Nurse  The nurse talked in a way that helped me under...
# 19                 Nurse  I felt confident in the nurse's ability to tre...
# 20                 Nurse                   I had enough time with the nurse
# 21    Care and treatment  Are you involved as much as you want to be in ...
# 22             Medicines      It was easy enough for me to get my medicines
# 23             Medicines     I knew enough about what my medicines were for
# 24             Medicines  I knew enough about possible side effects of m...
# 25             Medicines  I would know what to do if I had any problems ...
# 26          Overall care              I am treated with dignity and respect
# 27          Overall care       I am treated with kindness and understanding
# 28          Overall care  Overall, how would you rate the care provided ...
# 29          Out of Hours  Overall, how would you rate the care you exper...
# ...                  ...                                                ...
# 1638        Out of Hours                   The time I waited was reasonable
# 1639        Out of Hours  I felt that the person had all the information...
# 1640        Out of Hours                           I felt I was listened to
# 1641        Out of Hours  Things were explained to me in a way I could u...
# 1642        Out of Hours    I felt that I got the right treatment or advice
# 1643        Out of Hours  Overall, how would you rate the care you exper...
# 1644        Out of Hours                   The time I waited was reasonable
# 1645        Out of Hours  I felt that the person had all the information...
# 1646        Out of Hours                           I felt I was listened to
# 1647        Out of Hours  Things were explained to me in a way I could u...
# 1648        Out of Hours    I felt that I got the right treatment or advice
# 1649        Out of Hours  Overall, how would you rate the care you exper...
# 1650        Out of Hours                   The time I waited was reasonable
# 1651        Out of Hours  I felt that the person had all the information...
# 1652        Out of Hours                           I felt I was listened to
# 1653        Out of Hours  Things were explained to me in a way I could u...
# 1654        Out of Hours    I felt that I got the right treatment or advice
# 1655        Out of Hours  Overall, how would you rate the care you exper...
# 1656        Out of Hours                   The time I waited was reasonable
# 1657        Out of Hours  I felt that the person had all the information...
# 1658        Out of Hours                           I felt I was listened to
# 1659        Out of Hours  Things were explained to me in a way I could u...
# 1660        Out of Hours    I felt that I got the right treatment or advice
# 1661        Out of Hours  Overall, how would you rate the care you exper...
# 1662        Out of Hours                   The time I waited was reasonable
# 1663        Out of Hours  I felt that the person had all the information...
# 1664        Out of Hours                           I felt I was listened to
# 1665        Out of Hours  Things were explained to me in a way I could u...
# 1666        Out of Hours    I felt that I got the right treatment or advice
# 1667        Out of Hours  Overall, how would you rate the care you exper...
#
#                                characteristic         base_group  \
# 0                                      Gender             Female
# 1                                      Gender             Female
# 2                                      Gender             Female
# 3                                      Gender             Female
# 4                                      Gender             Female
# 5                                      Gender             Female
# 6                                      Gender             Female
# 7                                      Gender             Female
# 8                                      Gender             Female
# 9                                      Gender             Female
# 10                                     Gender             Female
# 11                                     Gender             Female
# 12                                     Gender             Female
# 13                                     Gender             Female
# 14                                     Gender             Female
# 15                                     Gender             Female
# 16                                     Gender             Female
# 17                                     Gender             Female
# 18                                     Gender             Female
# 19                                     Gender             Female
# 20                                     Gender             Female
# 21                                     Gender             Female
# 22                                     Gender             Female
# 23                                     Gender             Female
# 24                                     Gender             Female
# 25                                     Gender             Female
# 26                                     Gender             Female
# 27                                     Gender             Female
# 28                                     Gender             Female
# 29                                     Gender             Female
# ...                                       ...                ...
# 1638  First OOH service treated or advised by  Phone advice only
# 1639  First OOH service treated or advised by  Phone advice only
# 1640  First OOH service treated or advised by  Phone advice only
# 1641  First OOH service treated or advised by  Phone advice only
# 1642  First OOH service treated or advised by  Phone advice only
# 1643  First OOH service treated or advised by  Phone advice only
# 1644  First OOH service treated or advised by  Phone advice only
# 1645  First OOH service treated or advised by  Phone advice only
# 1646  First OOH service treated or advised by  Phone advice only
# 1647  First OOH service treated or advised by  Phone advice only
# 1648  First OOH service treated or advised by  Phone advice only
# 1649  First OOH service treated or advised by  Phone advice only
# 1650  First OOH service treated or advised by  Phone advice only
# 1651  First OOH service treated or advised by  Phone advice only
# 1652  First OOH service treated or advised by  Phone advice only
# 1653  First OOH service treated or advised by  Phone advice only
# 1654  First OOH service treated or advised by  Phone advice only
# 1655  First OOH service treated or advised by  Phone advice only
# 1656  First OOH service treated or advised by  Phone advice only
# 1657  First OOH service treated or advised by  Phone advice only
# 1658  First OOH service treated or advised by  Phone advice only
# 1659  First OOH service treated or advised by  Phone advice only
# 1660  First OOH service treated or advised by  Phone advice only
# 1661  First OOH service treated or advised by  Phone advice only
# 1662  First OOH service treated or advised by  Phone advice only
# 1663  First OOH service treated or advised by  Phone advice only
# 1664  First OOH service treated or advised by  Phone advice only
# 1665  First OOH service treated or advised by  Phone advice only
# 1666  First OOH service treated or advised by  Phone advice only
# 1667  First OOH service treated or advised by  Phone advice only
#
#                                           group  odds_ratio  conf_lower  \
# 0                                          Male       1.064       1.026
# 1                                          Male       0.774       0.742
# 2                                          Male       1.179       1.137
# 3                                          Male       1.240       1.195
# 4                                          Male       1.180       1.144
# 5                                          Male       1.223       1.174
# 6                                          Male       1.053       1.009
# 7                                          Male       1.076       1.015
# 8                                          Male       1.182       1.136
# 9                                          Male       1.192       1.120
# 10                                         Male       1.172       1.120
# 11                                         Male       1.244       1.183
# 12                                         Male       1.285       1.227
# 13                                         Male       1.169       1.118
# 14                                         Male       1.130       1.077
# 15                                         Male       1.207       1.111
# 16                                         Male       1.182       1.102
# 17                                         Male       1.323       1.219
# 18                                         Male       1.284       1.206
# 19                                         Male       1.248       1.160
# 20                                         Male       1.098       1.005
# 21                                         Male       0.910       0.870
# 22                                         Male       1.129       1.048
# 23                                         Male       0.829       0.771
# 24                                         Male       0.910       0.878
# 25                                         Male       0.796       0.760
# 26                                         Male       1.293       1.234
# 27                                         Male       1.179       1.131
# 28                                         Male       1.182       1.133
# 29                                         Male       0.920       0.868
# ...                                         ...         ...         ...
# 1638  Home visit \nfrom another \ndoctor/ nurse       1.146       1.017
# 1639  Home visit \nfrom another \ndoctor/ nurse       1.253       1.112
# 1640  Home visit \nfrom another \ndoctor/ nurse       1.582       1.370
# 1641  Home visit \nfrom another \ndoctor/ nurse       1.657       1.435
# 1642  Home visit \nfrom another \ndoctor/ nurse       1.996       1.755
# 1643  Home visit \nfrom another \ndoctor/ nurse       1.573       1.400
# 1644                           Emergency dental       1.396       1.097
# 1645                           Emergency dental       2.048       1.571
# 1646                           Emergency dental       1.471       1.119
# 1647                           Emergency dental       2.011       1.478
# 1648                           Emergency dental       2.381       1.825
# 1649                           Emergency dental       2.085       1.634
# 1650                                 Paramedics       2.698       2.340
# 1651                                 Paramedics       2.535       2.209
# 1652                                 Paramedics       3.102       2.616
# 1653                                 Paramedics       2.927       2.484
# 1654                                 Paramedics       3.751       3.232
# 1655                                 Paramedics       2.749       2.416
# 1656                           A&E / \nCasualty       0.921       0.840
# 1657                           A&E / \nCasualty       1.319       1.200
# 1658                           A&E / \nCasualty       1.237       1.115
# 1659                           A&E / \nCasualty       1.449       1.302
# 1660                           A&E / \nCasualty       1.691       1.539
# 1661                           A&E / \nCasualty       1.309       1.197
# 1662                                      Other       0.786       0.665
# 1663                                      Other       0.951       0.802
# 1664                                      Other       0.672       0.563
# 1665                                      Other       0.760       0.633
# 1666                                      Other       0.908       0.770
# 1667                                      Other       0.842       0.716
#
#       conf_upper
# 0          1.104
# 1          0.808
# 2          1.222
# 3          1.286
# 4          1.216
# 5          1.274
# 6          1.100
# 7          1.142
# 8          1.230
# 9          1.269
# 10         1.227
# 11         1.308
# 12         1.346
# 13         1.223
# 14         1.185
# 15         1.312
# 16         1.267
# 17         1.437
# 18         1.367
# 19         1.343
# 20         1.200
# 21         0.951
# 22         1.217
# 23         0.891
# 24         0.944
# 25         0.833
# 26         1.356
# 27         1.230
# 28         1.234
# 29         0.976
# ...          ...
# 1638       1.292
# 1639       1.412
# 1640       1.826
# 1641       1.913
# 1642       2.270
# 1643       1.768
# 1644       1.777
# 1645       2.668
# 1646       1.934
# 1647       2.736
# 1648       3.107
# 1649       2.661
# 1650       3.111
# 1651       2.909
# 1652       3.678
# 1653       3.450
# 1654       4.353
# 1655       3.128
# 1656       1.009
# 1657       1.449
# 1658       1.374
# 1659       1.613
# 1660       1.859
# 1661       1.431
# 1662       0.929
# 1663       1.128
# 1664       0.803
# 1665       0.912
# 1666       1.072
# 1667       0.990
#
# [1668 rows x 8 columns]

# %%
# df.to_csv('clean_data.csv')

# %%
df.groupby(['characteristic', 'group', 'base_group']).mean()#.to_csv('by_group.csv')
# Out:
#                                                                                                                  odds_ratio  \
# characteristic                                     group                                     base_group
# Age                                                Age                                       Mean age              1.015538
# Carers                                             Yes, 20-34 \nhours a week                 Not a carer           0.835176
#                                                    Yes, 35 or more hours a week              Not a carer           0.897206
#                                                    Yes, up to 19 hours a week                Not a carer           0.811088
# Deprivation (SIMD)                                 deprived-2                                Quintile 5            1.118333
#                                                    deprived-3                                Quintile 5            1.056400
#                                                    deprived-4                                Quintile 5            1.043933
#                                                    most deprived 1                           Quintile 5            1.188467
# Ethnicity                                          African, Caribbean or Black               White                 0.891842
#                                                    Asian                                     White                 0.713316
#                                                    Mixed                                     White                 0.946158
#                                                    Other                                     White                 0.645474
# First OOH service contacted                        999 Emergency service                     NHS24                 1.338167
#                                                    A&E / Casualty                            NHS24                 1.122667
#                                                    District /Ccommunity Nurse                NHS24                 1.928333
#                                                    My own GP surgery                         NHS24                 1.328167
#                                                    Other                                     NHS24                 1.270833
#                                                    Out of Hours Service                      NHS24                 1.108000
#                                                    Pharmacist / Chemist                      NHS24                 1.344167
# First OOH service treated or advised by            A&E / \nCasualty                          Phone advice only     1.321000
#                                                    Emergency dental                          Phone advice only     1.898667
#                                                    Home visit \nfrom another \ndoctor/ nurse Phone advice only     1.534500
#                                                    My own GP surgery                         Phone advice only     2.151500
#                                                    Other                                     Phone advice only     0.819833
#                                                    Out of Hours Service                      Phone advice only     1.679833
#                                                    Paramedics                                Phone advice only     2.960333
#                                                    Pharmacist / Chemist                      Phone advice only     2.353000
# Frequency of contact with GP Practice              5-10 times                                2-4 times             1.046960
#                                                    Can't remember / don't know               2-4 times             0.874360
#                                                    More than 10 times                        2-4 times             1.151720
# ...                                                                                                                     ...
# Long-term condition                                Deafness / Hearing Impairment             None                  0.872091
#                                                    Learning Disability                       None                  0.615000
#                                                    Mental Health Condition                   None                  0.891000
#                                                    Physical \nDisability                     None                  1.186920
# Percentage of GP practice list in 15% of most d... Estimate                                  Mean                  0.992143
# Religion                                           Another religion (non-Christian)          Church of Scotland    0.737281
#                                                    Buddhist                                  Church of Scotland    0.747625
#                                                    Hindu                                     Church of Scotland    1.059906
#                                                    Jewish                                    Church of Scotland    0.898531
#                                                    Muslim                                    Church of Scotland    0.794562
#                                                    None                                      Church of Scotland    0.850844
#                                                    Other Christian                           Church of Scotland    0.915531
#                                                    Pagan                                     Church of Scotland    0.837469
#                                                    Roman Catholic                            Church of Scotland    0.964344
#                                                    Sikh                                      Church of Scotland    0.881625
# Sexual orientation                                 Bisexual                                  Heterosexual          0.980077
#                                                    Gay or lesbian                            Heterosexual          0.944923
#                                                    Not answered                              Heterosexual          0.880077
#                                                    Other                                     Heterosexual          0.792923
# Urban-Rural                                        Accessible rural                          Large urban areas     0.973900
#                                                    Accessible small towns                    Large urban areas     0.887600
#                                                    Other Urban Areas                         Large urban areas     0.947900
#                                                    Remote Rural                              Large urban areas     1.178100
#                                                    Remote Small Towns                        Large urban areas     1.019400
# Work Status                                        Do not work due to illness or disability  Retired               1.028154
#                                                    In full-time education or training        Retired               0.756154
#                                                    Other                                     Retired               0.773974
#                                                    Unemployed / Looking for work             Retired               0.829051
#                                                    Work full time                            Retired               0.707436
#                                                    Work part time                            Retired               0.813256
#
#                                                                                                                  conf_lower  \
# characteristic                                     group                                     base_group
# Age                                                Age                                       Mean age              1.013051
# Carers                                             Yes, 20-34 \nhours a week                 Not a carer           0.705176
#                                                    Yes, 35 or more hours a week              Not a carer           0.813471
#                                                    Yes, up to 19 hours a week                Not a carer           0.751059
# Deprivation (SIMD)                                 deprived-2                                Quintile 5            1.029533
#                                                    deprived-3                                Quintile 5            0.976800
#                                                    deprived-4                                Quintile 5            0.965333
#                                                    most deprived 1                           Quintile 5            1.086333
# Ethnicity                                          African, Caribbean or Black               White                 0.628947
#                                                    Asian                                     White                 0.572421
#                                                    Mixed                                     White                 0.699737
#                                                    Other                                     White                 0.477474
# First OOH service contacted                        999 Emergency service                     NHS24                 1.117333
#                                                    A&E / Casualty                            NHS24                 1.011333
#                                                    District /Ccommunity Nurse                NHS24                 1.297167
#                                                    My own GP surgery                         NHS24                 1.117333
#                                                    Other                                     NHS24                 1.007333
#                                                    Out of Hours Service                      NHS24                 0.950167
#                                                    Pharmacist / Chemist                      NHS24                 1.080667
# First OOH service treated or advised by            A&E / \nCasualty                          Phone advice only     1.198833
#                                                    Emergency dental                          Phone advice only     1.454000
#                                                    Home visit \nfrom another \ndoctor/ nurse Phone advice only     1.348167
#                                                    My own GP surgery                         Phone advice only     1.824833
#                                                    Other                                     Phone advice only     0.691500
#                                                    Out of Hours Service                      Phone advice only     1.534167
#                                                    Paramedics                                Phone advice only     2.549500
#                                                    Pharmacist / Chemist                      Phone advice only     1.854833
# Frequency of contact with GP Practice              5-10 times                                2-4 times             0.989040
#                                                    Can't remember / don't know               2-4 times             0.725400
#                                                    More than 10 times                        2-4 times             1.065920
# ...                                                                                                                     ...
# Long-term condition                                Deafness / Hearing Impairment             None                  0.803455
#                                                    Learning Disability                       None                  0.506286
#                                                    Mental Health Condition                   None                  0.804077
#                                                    Physical \nDisability                     None                  1.074240
# Percentage of GP practice list in 15% of most d... Estimate                                  Mean                  0.988905
# Religion                                           Another religion (non-Christian)          Church of Scotland    0.556156
#                                                    Buddhist                                  Church of Scotland    0.510562
#                                                    Hindu                                     Church of Scotland    0.607563
#                                                    Jewish                                    Church of Scotland    0.479625
#                                                    Muslim                                    Church of Scotland    0.614312
#                                                    None                                      Church of Scotland    0.799563
#                                                    Other Christian                           Church of Scotland    0.831844
#                                                    Pagan                                     Church of Scotland    0.638406
#                                                    Roman Catholic                            Church of Scotland    0.893562
#                                                    Sikh                                      Church of Scotland    0.571094
# Sexual orientation                                 Bisexual                                  Heterosexual          0.728538
#                                                    Gay or lesbian                            Heterosexual          0.776385
#                                                    Not answered                              Heterosexual          0.763692
#                                                    Other                                     Heterosexual          0.643154
# Urban-Rural                                        Accessible rural                          Large urban areas     0.861250
#                                                    Accessible small towns                    Large urban areas     0.772550
#                                                    Other Urban Areas                         Large urban areas     0.842800
#                                                    Remote Rural                              Large urban areas     0.993950
#                                                    Remote Small Towns                        Large urban areas     0.828950
# Work Status                                        Do not work due to illness or disability  Retired               0.906821
#                                                    In full-time education or training        Retired               0.633821
#                                                    Other                                     Retired               0.673590
#                                                    Unemployed / Looking for work             Retired               0.702590
#                                                    Work full time                            Retired               0.646154
#                                                    Work part time                            Retired               0.733179
#
#                                                                                                                  conf_upper
# characteristic                                     group                                     base_group
# Age                                                Age                                       Mean age              1.018026
# Carers                                             Yes, 20-34 \nhours a week                 Not a carer           0.991294
#                                                    Yes, 35 or more hours a week              Not a carer           0.990382
#                                                    Yes, up to 19 hours a week                Not a carer           0.876000
# Deprivation (SIMD)                                 deprived-2                                Quintile 5            1.215333
#                                                    deprived-3                                Quintile 5            1.143267
#                                                    deprived-4                                Quintile 5            1.129333
#                                                    most deprived 1                           Quintile 5            1.300800
# Ethnicity                                          African, Caribbean or Black               White                 1.277474
#                                                    Asian                                     White                 0.892842
#                                                    Mixed                                     White                 1.289632
#                                                    Other                                     White                 0.877158
# First OOH service contacted                        999 Emergency service                     NHS24                 1.602500
#                                                    A&E / Casualty                            NHS24                 1.246000
#                                                    District /Ccommunity Nurse                NHS24                 2.871167
#                                                    My own GP surgery                         NHS24                 1.578667
#                                                    Other                                     NHS24                 1.603167
#                                                    Out of Hours Service                      NHS24                 1.292333
#                                                    Pharmacist / Chemist                      NHS24                 1.672333
# First OOH service treated or advised by            A&E / \nCasualty                          Phone advice only     1.455833
#                                                    Emergency dental                          Phone advice only     2.480500
#                                                    Home visit \nfrom another \ndoctor/ nurse Phone advice only     1.746833
#                                                    My own GP surgery                         Phone advice only     2.537333
#                                                    Other                                     Phone advice only     0.972333
#                                                    Out of Hours Service                      Phone advice only     1.839000
#                                                    Paramedics                                Phone advice only     3.438167
#                                                    Pharmacist / Chemist                      Phone advice only     2.986333
# Frequency of contact with GP Practice              5-10 times                                2-4 times             1.108920
#                                                    Can't remember / don't know               2-4 times             1.056760
#                                                    More than 10 times                        2-4 times             1.245280
# ...                                                                                                                     ...
# Long-term condition                                Deafness / Hearing Impairment             None                  0.947273
#                                                    Learning Disability                       None                  0.748286
#                                                    Mental Health Condition                   None                  0.987923
#                                                    Physical \nDisability                     None                  1.312840
# Percentage of GP practice list in 15% of most d... Estimate                                  Mean                  0.995333
# Religion                                           Another religion (non-Christian)          Church of Scotland    0.983906
#                                                    Buddhist                                  Church of Scotland    1.104250
#                                                    Hindu                                     Church of Scotland    1.915531
#                                                    Jewish                                    Church of Scotland    1.763094
#                                                    Muslim                                    Church of Scotland    1.034031
#                                                    None                                      Church of Scotland    0.905781
#                                                    Other Christian                           Church of Scotland    1.008469
#                                                    Pagan                                     Church of Scotland    1.104250
#                                                    Roman Catholic                            Church of Scotland    1.041375
#                                                    Sikh                                      Church of Scotland    1.375031
# Sexual orientation                                 Bisexual                                  Heterosexual          1.325231
#                                                    Gay or lesbian                            Heterosexual          1.153154
#                                                    Not answered                              Heterosexual          1.015769
#                                                    Other                                     Heterosexual          0.979692
# Urban-Rural                                        Accessible rural                          Large urban areas     1.101550
#                                                    Accessible small towns                    Large urban areas     1.020600
#                                                    Other Urban Areas                         Large urban areas     1.066600
#                                                    Remote Rural                              Large urban areas     1.398050
#                                                    Remote Small Towns                        Large urban areas     1.255400
# Work Status                                        Do not work due to illness or disability  Retired               1.167692
#                                                    In full-time education or training        Retired               0.904641
#                                                    Other                                     Retired               0.890872
#                                                    Unemployed / Looking for work             Retired               0.980974
#                                                    Work full time                            Retired               0.775205
#                                                    Work part time                            Retired               0.903051
#
# [74 rows x 3 columns]

# %%
df.characteristic.unique()
# Out:
# array(['Gender', 'Age', 'Ethnicity', 'Religion', 'Sexual orientation',
#        'Deprivation (SIMD)', 'Urban-Rural', 'Work Status', 'Carers',
#        'Health status', 'Limitation of day-to-day activities',
#        'Interpretation, translation or other communication support needs',
#        'Long-term condition', 'GP Practice Size',
#        'Percentage of GP practice list in 15% of most deprived areas',
#        'Frequency of contact with GP Practice',
#        'First OOH service contacted',
#        'First OOH service treated or advised by'], dtype=object)
